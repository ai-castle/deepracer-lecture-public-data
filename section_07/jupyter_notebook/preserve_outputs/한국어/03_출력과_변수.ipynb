# %% [markdown]
# # **출력과 변수**

# %% [markdown]
# ## **1. print 함수**

# %% [markdown]
# **1.1. `print(출력내용)` : 내용을 출력**

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
print(1+2)
# Out:
# 3

# %%
print("Hello, World")
print(1+2)
# Out:
# Hello, World
# 3

# %% [markdown]
# **1.2. 콤마(,)를 사용하여 여러개를 연달아 출력이 가능합니다.**

# %%
print("Hello, World", 1+2)
# Out:
# Hello, World 3

# %% [markdown]
# ## **2. 주석 달기**
#
# - `# 주석내용`
# - 주석에 코드 설명을 적어 놓으면 보기 편하다
# - 주석처리 된 구문은 코드 실행에 적용되지 않는다.

# %% [markdown]
# **2.1. 우측 끝에 주석**

# %%
print("Hello, World") # 인사 문구
print(1+2)  # 1과 2의 합을 계산
# Out:
# Hello, World
# 3

# %% [markdown]
# **2.2. 줄 전체에 주석**
# - 줄 전체 주석 단축키 : ctrl + /

# %%
# 인사 문구
print("Hello, World")

# 1과 2의 합을 계산
print(1+2)
# Out:
# Hello, World
# 3

# %% [markdown]
# ## **3. 변수에 값 대입**
#
# - `변수명 = 값`

# %% [markdown]
# **3.1. 변수 하나 만들기**

# %%
# 변수 만들기
x = 1

print(x+2)
# Out:
# 3

# %% [markdown]
# **3.2. 변수를 이용해서 또 다른 변수 만들기**

# %%
# 변수 만들기
x = 1

# 변수에 숫자 더하여 새 변수 생성
y = x + 2

print(y)
# Out:
# 3

# %% [markdown]
# **3.3. 변수 값 업데이트**

# %%
# 변수 만들기
x = 1

# 자기 자신에 수 더하기
x = x + 1

print(x)
# Out:
# 2

# %% [markdown]
# **3.4. 문자 이후에 숫자가 나오는 변수명은 가능**

# %%
hello1 = "안녕하세요"
print(hello1)
# Out:
# 안녕하세요

# %% [markdown]
# **3.5. 숫자 이후에 문자가 나오는 변수명은 불가**

# %%
1hello = "안녕하세요"
# Out:
#   File "<ipython-input-11-e19408c8a2c1>", line 1
#     1hello = "안녕하세요"
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# **3.6. 변수명에 띄어쓰기 불가**

# %%
greet person = "안녕하세요 여러분"
# Out:
#   File "<ipython-input-12-68dc9a277bff>", line 1
#     greet person = "안녕하세요 여러분"
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# **3.7. 변수명에 띄어쓰기를 넣고 싶은 경우, 주로 언더바 (_)를 이용**

# %%
greet_person = "안녕하세요 여러분"
print(greet_person)
# Out:
# 안녕하세요 여러분
