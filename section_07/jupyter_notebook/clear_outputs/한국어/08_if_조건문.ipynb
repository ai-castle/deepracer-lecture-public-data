# %% [markdown]
# # **if 조건문**

# %% [markdown]
# - if 문은 조건에 따라서 실행 여부를 결정하는 제어문입니다.

# %% [markdown]
# ## **예시 1**
# - 구조
#   ```python
#   if 조건:
#       실행 코드
#   ```
# - 주의 : 조건문 끝에 콜론( : ) 을 붙여줘야 하며 하위 코드는 반드시 들여쓰기 (Tab 또는 Space 4번)을 해야 한다.

# %%
x = 10

if x > 20 :
    print("20보다 큽니다.")

# %% [markdown]
# ## **예시 2**
# - 구조
#   ```python
#   if 조건1:
#       실행 코드 1
#   else :
#       실행 코드 2
#   ```
#
# - if 는 최초의 조건문이고, elif 는 위 조건을 만족하지 않을 시 시작되는 조건문이다.

# %%
x = 100

if (0 < x) and (x < 20) :
    print("0과 20사이 입니다.")
else :
    print("0 이하 또는 20 이상입니다.")

# %% [markdown]
# ## **예시 3**
# - 구조
#   ```python
#   if 조건1:
#       실행 코드 1
#   elif 조건2:
#       실행 코드 2
#   else :
#       실행 코드 3
#   ```
#
# - else 는 어느 조건도 만족하지 않을 시 실행되는 코드이다.
# - 만약 if 또는 elif의 어떤 조건을 만족하면 해당 코드블럭만 실행되고 다른 코드블럭은 실행되지 않는다.

# %%
x = 3

if x > 20 :
    print("20보다 큽니다.")
elif x > 10 :
    print("20보다 크지 않고 10보다 큽니다.")
else :
    print("10보다 크지 않습니다.")

# %% [markdown]
# ## 예시 4
#
# - 구조
#   ```python
#   if 조건1:
#       실행 코드 1
#   elif 조건2:
#       실행 코드 2
#   elif 조건3:
#       실행 코드 3
#   else :
#       실행 코드 4
#   ```
#
# - elif의 개수에는 제한이 없다.

# %%
x = -15

if x > 20 :
    print("20보다 큽니다.")
elif x > 10 :
    print("20보다 크지 않고 10보다 큽니다.")
elif x > 0 :
    print("10보다 크지 않고 0 보다 큽니다.")
else :
    print("0보다 작거나 같습니다.")
